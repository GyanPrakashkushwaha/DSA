# %%
word = 'A man, a plan, a canal: Panama'

# %%
import string

# %%
string.punctuation
# Out:
# '!"#$%&\'()*+,-./:;<=>?@[\\]^_`{|}~'

# %%
for i in word:
    if i in string.punctuation:
        word = word.replace(i, '')

# print(word)
word = word.lower()
word = word.replace(' ', '')
n = len(word)
ispalin = True
for i in range(n//2):
    # print(i)
    if word[i] == word[n-i-1]:
        print(word[i])
print(ispalin)
# Out:
# a
# m
# a
# n
# a
# p
# l
# a
# n
# a
# True

# %%
word.replace(, '').lower()
# Out:
# 'a man, a plan, a canal: panama'

# %%
d = {2: 14, 3: 13}
sorted_d = sorted(d.items(), key = lambda x: x[1], reverse=True)
sorted_d
# Out:
# [(2, 14), (3, 13)]

# %%
nums = [1,1,1,2,2,3]
mapp = {}
for num in nums:
    mapp[num] = mapp.get(num, 0) + 1
# mapp = sorted(mapp.items(), key = lambda x: x[1], reverse = True)
# potential = [num for _, num in mapp]
print(mapp, '\n' , potential)
# Out:
# {1: 3, 2: 2, 3: 1}
#  [3, 2, 1]

# %%
import heapq
def xSum(nums, x):
    mapp = {}
    for num in nums:
        mapp[num] = mapp.get(num, 0) + 1
    
    heap = []
    for key, freq in mapp.items():
        heapq.heappush(heap, (-freq, key))
    
    ans = 0
    for _ in range(x):
        freq, key = heapq.heappop(heap)
        ans += -freq*key
        
    return ans
    
xSum([1,1,2,2,3,4, 3, 4], 2)
# Out:
# 6

# %%
nums = [1,1,2,2,3,4, 3, 4]
nums[0:6]
# Out:
# [1, 1, 2, 2, 3, 4]
