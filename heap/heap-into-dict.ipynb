# %%
import heapq
from collections import defaultdict

# %%
heap = []
D = defaultdict(list)
heapq.heappush(heap, 2)

# %%
cousins = defaultdict(list)

# %%
heapq.heappush(cousins[0], 2)
heapq.heappush(cousins[0], 3)
# heapq.heappush(cousins[0], 12)
# heapq.heappush(cousins[0], 5)

# %%
# heapq.heappop(cousins[0])

# %%
cousins[0]
# Out:
# [2, 3, 3]

# %%
cousins[0][0]
# Out:
# 3

# %%
heap[1]
# Out:
# 1
