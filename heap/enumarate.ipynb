# %%
points = [[1,3],[-2,2]]
for i, l in enumerate(points):
    print(i, (l[0]**2 + l[1]**2)**0.5)
# Out:
# 0 3.1622776601683795
# 1 2.8284271247461903

# %%
nums = [3,2,1,5,6,4] 
nums
# Out:
# []

# %%
# START
input1 = int(input("input 1"))
input2 = int(input("input 2"))

subtraction = input1 -input2
print("The result is:",subtraction)
# END
# Out:
# The result is: 1
