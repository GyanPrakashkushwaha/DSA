# %%
9^6
# Out:
# 15

# %%
bin(15)
# Out:
# '0b1111'

# %%
bin(9), bin(6)
# Out:
# ('0b1001', '0b110')

# %%
bin(int(input()))
# Out:
# '0b111'

# %%
int(input()) ^ int(input())
# Out:
# 9

# %%
3^5
# Out:
# 6

# %%
3 & 1 == 0
# Out:
# False
