# %%
[[2] ,[23]]
# Out:
# [[2], [23]]

# %%
for a in set([[123],[4],[5],[5]]):
    print(type(a))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 for a in set([[123],[4],[5],[5]]):
#       2     print(type(a))
#
# TypeError: unhashable type: 'list'

# %%
res = ['a', 'b', 'c']
s2 = 'def'
for i in range(len(res)):
    for j in range(len(s2)):
        res.append(res[i] + s2[j])
    # res.pop(0)
res
# Out:
# ['a', 'b', 'c', 'ad', 'ae', 'af', 'bd', 'be', 'bf', 'cd', 'ce', 'cf']

# %%
'ab'[1:]
# Out:
# 'b'
