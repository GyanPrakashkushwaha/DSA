# %%
num = [1, 2, 3]
# 0, 1, 2

# %%
num.remove(2)

# %%
num
# Out:
# [1, 3]

# %%
num[0:] + num[:]
# Out:
# [1, 2, 3, 1, 2]

# %%
[] + [2]
# Out:
# [2]

# %%
"".join([str(i+1) for i in range(3)])
# Out:
# '123'

# %%
s = 'abc'
s[1] = 'd'
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[35], line 2
#       1 s = 'abc'
# ----> 2 s[1] = 'd'
#
# TypeError: 'str' object does not support item assignment

# %%
nums = [1,23,4]
nums.reverse()

# %%
nums[:-1]
# Out:
# [4, 23]

# %%
nums.index(2)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[42], line 1
# ----> 1 nums.index(2)
#
# ValueError: 2 is not in list

# %%
nums.pop()
nums.pop()
# Out:
# 23

# %%
nums[-1]
# Out:
# 4

# %%
strs = ['']
strs[0] -= 'a'

strs
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[6], line 2
#       1 strs = ['']
# ----> 2 strs[0] -= 'a'
#       4 strs
#
# TypeError: unsupported operand type(s) for -=: 'str' and 'str'

# %%
strs = '()())()' 
      # 0123456
strs[:3] + strs[3+1:]
# Out:
# '()()()'

# %%
mysting = "abaa"
mysting == mysting[::-1]
# Out:
# False

# %%
myset = set([1, 2, 3,])
myset
# Out:
# {1, 2, 3}

# %%
myset.discard(4)

# %%
nums = [1, 2, 3]
"->".join([str(num) for num in nums])
# Out:
# '1->2->3'

# %%
ord("a") -97
# Out:
# 0

# %%
path = ['a', 'b', 'c']
val = 0
string = ''
for i in range(len(path)-1, -1, -1):
    val += ord(path[i]) -97
    # string += c
    print(path[i])
    
val
# Out:
# c
# b
# a
# 3

# %%
chr(97)
# Out:
# 'a'

# %%
res_path = [0, 1, 2]
"".join([chr(val + 97) for val in (res_path)])
# Out:
# 'abc'
